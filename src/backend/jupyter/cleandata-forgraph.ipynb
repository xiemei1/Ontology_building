# %%
import pandas as pd
df = pd.read_csv('result.csv')
df
# Out:
#       Unnamed: 0  Unnamed: 0.1                                           id  \
# 0              0             0  uk.org.publicwhip/debate/1979-11-27a.1096.7
# 1              1             1  uk.org.publicwhip/debate/1979-11-27a.1136.2
# 2              2             2  uk.org.publicwhip/debate/1979-11-29a.1477.7
# 3              3             3  uk.org.publicwhip/debate/1979-11-12a.1080.3
# 4              4             4  uk.org.publicwhip/debate/1979-11-29a.1470.2
# ...          ...           ...                                          ...
# 9995        9995          9995  uk.org.publicwhip/debate/2021-02-24a.1024.2
# 9996        9996          9996   uk.org.publicwhip/debate/2021-04-28c.361.4
# 9997        9997          9997   uk.org.publicwhip/debate/2021-02-22b.655.7
# 9998        9998          9998  uk.org.publicwhip/debate/2021-02-04b.1186.0
# 9999        9999          9999     uk.org.publicwhip/debate/2021-01-11c.6.3
#
# ...

# %%
df_version = pd.read_csv('version.csv')
df_version
# Out:
#       Unnamed: 0  Unnamed: 0.1   doc    topic1    topic2    topic3    topic4  \
# 0              0             0     0  0.193974  0.165725  0.171375  0.158192
# 1              1             1     1  0.130208  0.131944  0.295139  0.171875
# 2              2             2     2  0.224014  0.139785  0.155914  0.197133
# 3              3             3     3  0.160256  0.160256  0.160256  0.179487
# 4              4             4     4  0.160256  0.181624  0.177350  0.160256
# ...          ...           ...   ...       ...       ...       ...       ...
# 9995        9995          9995  9995  0.128205  0.135043  0.184615  0.164103
# 9996        9996          9996  9996  0.242123  0.145937  0.175788  0.152570
# 9997        9997          9997  9997  0.164103  0.194872  0.155556  0.174359
# 9998        9998          9998  9998  0.164158  0.189964  0.324014  0.092473
# 9999        9999          9999  9999  0.194030  0.223881  0.150912  0.124378
#
# ...

# %%
# for i in range(len(df['nVn'])):
#     y = df['nVn'][i]
#     length = len(y)
#     if length >0:
#         for j in range(length):
#             if len(y[j])>=3:
#                 y[j][1],y[j][2] = y[j][2],y[j][1]
#             else:
#                 break
        
nvn = df['nVn'].tolist()
new_nvn = []
for i in range(len(nvn)):
    m = eval(nvn[i])
    tmp = []
    for j in range(len(m)):
        m[j][1],m[j][2] = m[j][2],m[j][1]
        
    new_nvn.append(m)

# %%
for i in range(len(new_nvn)):
    new_nvn[i] = str(new_nvn[i])

# %%
from pandas.core.frame import DataFrame
c={"newc_nvn" : new_nvn,}#将列表a，b转换成字典
data=DataFrame(c)

# %%
data
# Out:
#                                                newc_nvn
# 0     [['shells', 'Is', 'vessels'], ['they', 'Is', '...
# 1     [['Gentleman', 'contradicting', 'himself'], ['...
# 2     [['colour', 'recall', 'British citizens'], ['h...
# 3                                                    []
# 4                     [['breeding herd', 'was', 'pig']]
# ...                                                 ...
# 9995      [['following provisions', 'made', 'January']]
# 9996  [['COP26', 'have', 'Scotland'], ['that', 'brin...
# 9997  [['Boris Johnson', 'am', 'hon'], ['who', 'supp...
# 9998  [['Robert Halfon', 'welcome', 'hon'], ['Harlow...
# 9999  [['risk', 'are', 'ban'], ['covid crisis', 'hig...
#
# [10000 rows x 1 columns]

# %%
df['new_nvn'] = data['newc_nvn']

# %%
df_version['name_entities']= df['Name_enitity']

# %%
df_version['relation'] = df['nPn'] +df['nn']

# %%
df_version
# Out:
#       Unnamed: 0  Unnamed: 0.1   doc    topic1    topic2    topic3    topic4  \
# 0              0             0     0  0.193974  0.165725  0.171375  0.158192
# 1              1             1     1  0.130208  0.131944  0.295139  0.171875
# 2              2             2     2  0.224014  0.139785  0.155914  0.197133
# 3              3             3     3  0.160256  0.160256  0.160256  0.179487
# 4              4             4     4  0.160256  0.181624  0.177350  0.160256
# ...          ...           ...   ...       ...       ...       ...       ...
# 9995        9995          9995  9995  0.128205  0.135043  0.184615  0.164103
# 9996        9996          9996  9996  0.242123  0.145937  0.175788  0.152570
# 9997        9997          9997  9997  0.164103  0.194872  0.155556  0.174359
# 9998        9998          9998  9998  0.164158  0.189964  0.324014  0.092473
# 9999        9999          9999  9999  0.194030  0.223881  0.150912  0.124378
#
# ...

# %%
df_version['relation'][8]
# Out:
# "[['remarks', 'about', 'policy'], ['policy', 'by', 'hon'], ['result', 'of', 'policies'], ['upturn', 'in', 'investment'], ['upturn', 'in', 'sector'], ['employment', 'in', 'London'], ['adjustments', 'to', 'policy'], ['interest', 'in', 'amount'], ['amount', 'of', 'money'], ['standards', 'of', 'people'], ['people', 'in', 'area'], ['interest', 'as', 'director'], ['director', 'of', 'company'], ['hall', 'at', 'Garden'], ['fault', 'of', 'Government'], ['reduction', 'in', 'expenditure'], ['expenditure', 'on', 'services'], ['reduction', 'in', 'breach'], ['breach', 'of', 'pledge'], ['result', 'of', 'increase'], ['transfer', 'of', 'resources'], ['breach', 'of', 'promise'], ['breach', 'by', 'Government'], ['councils', 'in', 'London'], ['sort', 'of', 'people'], ['sort', 'of', 'prices'], ['register', 'of', 'land'], ['disposal', 'to', 'sector'], ['register', 'of', 'property'], ['companies', 'in', 'country']][['Frank Dobson', 'hon', 'understand'], ['1945', 'what', 'is'], ['original blitz', '1945', 'c
# ...

# %%
df_version.to_csv('version1.csv')
