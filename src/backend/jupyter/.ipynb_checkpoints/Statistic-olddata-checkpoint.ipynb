# %%
import spacy
from pandas.core.frame import DataFrame
import pandas as pd
from IPython.core.display import display, HTML
import json
nlp = spacy.load('en_core_web_sm')

# %%
def getText():
    f = open('../data/texts.json',)
    data = json.load(f)
    content_debates = data['debates']
    text= content_debates.replace("\n"," ")
    return text
def sw_removal(text):
    sw_spacy = nlp.Defaults.stop_words
    words = [word for word in text.split() if word.lower() not in sw_spacy]
    new_text = " ".join(words)
    return new_text
doc = sw_removal(getText())
document = nlp(doc)
t = [sent.text for sent in document.sents]
#c={"ID" : range(len(t)),"sen" : t}
df=DataFrame(t)
df.columns = ['text']
display(df)
# Out:
#                                                    text
# 0     Good evening Hofstra University Hempstead, New...
# 1               Lester Holt, anchor "NBC Nightly News.”
# 2                     want welcome presidential debate.
# 3     participants tonight Donald Trump Hillary Clin...
# 4     debate sponsored Commission Presidential Debat...
# ...                                                 ...
# 3520                             thing agree hope vote.
# 3521           honors obligations living great country.
# 3522                                  Thank good night.
# 3523                                                  [
# 3524                                         Applause ]
#
# [3525 rows x 1 columns]

# %%
def extract_named_ents(text):
    return [(ent.text, ent.label_) for ent in nlp(text).ents]

def add_named_ents(df):
    df['named_ents'] = df['text'].apply(extract_named_ents) 
add_named_ents(df)
display(df) #可以提取名词短语和entity做对比
# Out:
#                                                    text  \
# 0     Good evening Hofstra University Hempstead, New...
# 1               Lester Holt, anchor "NBC Nightly News.”
# 2                     want welcome presidential debate.
# 3     participants tonight Donald Trump Hillary Clin...
# 4     debate sponsored Commission Presidential Debat...
# ...                                                 ...
# 3520                             thing agree hope vote.
# 3521           honors obligations living great country.
# 3522                                  Thank good night.
# 3523                                                  [
# 3524                                         Applause ]
#
#                                              named_ents
# 0     [(Hofstra University Hempstead, ORG), (New Yor...
# 1      [(Lester Holt, PERSON), (NBC Nightly News, ORG)]
# 2                                                    []
# 3     [(Donald Trump, PERSON), (Hillary Clinton, PER...
# 4              [(Commission Presidential Debates, ORG)]
# ...                                                 ...
# 3520                                                 []
# 3521                                                 []
# 3522                                    [(night, TIME)]
# 3523                                                 []
# 3524                                                 []
#
# [3525 rows x 2 columns]

# %%
def extract_nouns(text):
    keep_pos = ['PROPN', 'NOUN']
    return [(tok.text, tok.pos_) for tok in nlp(text) if tok.pos_ in keep_pos]

def add_nouns(df):
   
    df['nouns'] = df['text'].apply(extract_nouns)
add_nouns(df)
display(df)
# Out:
#                                                    text  \
# 0     Good evening Hofstra University Hempstead, New...
# 1               Lester Holt, anchor "NBC Nightly News.”
# 2                     want welcome presidential debate.
# 3     participants tonight Donald Trump Hillary Clin...
# 4     debate sponsored Commission Presidential Debat...
# ...                                                 ...
# 3520                             thing agree hope vote.
# 3521           honors obligations living great country.
# 3522                                  Thank good night.
# 3523                                                  [
# 3524                                         Applause ]
#
#                                              named_ents  \
# 0     [(Hofstra University Hempstead, ORG), (New Yor...
# 1      [(Lester Holt, PERSON), (NBC Nightly News, ORG)]
# 2                                                    []
# 3     [(Donald Trump, PERSON), (Hillary Clinton, PER...
# 4              [(Commission Presidential Debates, ORG)]
# ...                                                 ...
# 3520                                                 []
# 3521                                                 []
# 3522                                    [(night, TIME)]
# 3523                                                 []
# 3524                                                 []
#
#                                                   nouns
# 0     [(evening, NOUN), (Hofstra, PROPN), (Universit...
# 1     [(Lester, PROPN), (Holt, PROPN), (anchor, NOUN...
# 2                                      [(debate, NOUN)]
# 3     [(participants, NOUN), (tonight, NOUN), (Donal...
# 4     [(debate, NOUN), (Commission, PROPN), (Preside...
# ...                                                 ...
# 3520        [(thing, NOUN), (hope, NOUN), (vote, NOUN)]
# 3521  [(honors, NOUN), (obligations, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
# [3525 rows x 3 columns]

# %%
def extract_named_nouns(row_series):
    ents = set()
    idxs = set()
    # remove duplicates and merge two lists together
    for noun_tuple in row_series['nouns']:
        for named_ents_tuple in row_series['named_ents']:
            if noun_tuple[1] == named_ents_tuple[1]: 
                idxs.add(noun_tuple[1])
                ents.add(named_ents_tuple)
        if noun_tuple[1] not in idxs:
            ents.add(noun_tuple)
    
    return sorted(list(ents), key=lambda x: x[1])

def add_named_nouns(df):
    df['named_nouns'] = df.apply(extract_named_nouns, axis=1)
add_named_nouns(df)
display(df)
# Out:
#                                                    text  \
# 0     Good evening Hofstra University Hempstead, New...
# 1               Lester Holt, anchor "NBC Nightly News.”
# 2                     want welcome presidential debate.
# 3     participants tonight Donald Trump Hillary Clin...
# 4     debate sponsored Commission Presidential Debat...
# ...                                                 ...
# 3520                             thing agree hope vote.
# 3521           honors obligations living great country.
# 3522                                  Thank good night.
# 3523                                                  [
# 3524                                         Applause ]
#
#                                              named_ents  \
# 0     [(Hofstra University Hempstead, ORG), (New Yor...
# 1      [(Lester Holt, PERSON), (NBC Nightly News, ORG)]
# 2                                                    []
# 3     [(Donald Trump, PERSON), (Hillary Clinton, PER...
# 4              [(Commission Presidential Debates, ORG)]
# ...                                                 ...
# 3520                                                 []
# 3521                                                 []
# 3522                                    [(night, TIME)]
# 3523                                                 []
# 3524                                                 []
#
#                                                   nouns  \
# 0     [(evening, NOUN), (Hofstra, PROPN), (Universit...
# 1     [(Lester, PROPN), (Holt, PROPN), (anchor, NOUN...
# 2                                      [(debate, NOUN)]
# 3     [(participants, NOUN), (tonight, NOUN), (Donal...
# 4     [(debate, NOUN), (Commission, PROPN), (Preside...
# ...                                                 ...
# 3520        [(thing, NOUN), (hope, NOUN), (vote, NOUN)]
# 3521  [(honors, NOUN), (obligations, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
#                                             named_nouns
# 0     [(evening, NOUN), (New, PROPN), (University, P...
# 1     [(anchor, NOUN), (Nightly, PROPN), (NBC, PROPN...
# 2                                      [(debate, NOUN)]
# 3     [(tonight, NOUN), (participants, NOUN), (Trump...
# 4     [(debate, NOUN), (organization, NOUN), (Debate...
# ...                                                 ...
# 3520        [(hope, NOUN), (thing, NOUN), (vote, NOUN)]
# 3521  [(obligations, NOUN), (honors, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
# [3525 rows x 4 columns]

# %%
def extract_compounds(text):
    
    comp_idx = 0
    compound = []
    compound_nps = []
    tok_idx = 0
    for idx, tok in enumerate(nlp(text)):
        if tok.dep_ == 'compound':

            # capture hyphenated compounds
            children = ''.join([c.text for c in tok.children])
            if '-' in children:
                compound.append(''.join([children, tok.text]))
            else:
                compound.append(tok.text)

            # remember starting index of first child in compound or word
            try:
                tok_idx = [c for c in tok.children][0].idx
            except IndexError:
                if len(compound) == 1:
                    tok_idx = tok.idx
            comp_idx = tok.i

        # append the last word in a compound phrase
        if tok.i - comp_idx == 1:
            compound.append(tok.text)
            if len(compound) > 1: 
                compound = ' '.join(compound)
                compound_nps.append((compound))

            # reset parameters
            tok_idx = 0 
            compound = []

    return compound_nps

def add_compounds(df):
   
    df['compounds'] = df['text'].apply(extract_compounds)
add_compounds(df) #用来做第一种方法的对比
display(df)
# Out:
#                                                    text  \
# 0     Good evening Hofstra University Hempstead, New...
# 1               Lester Holt, anchor "NBC Nightly News.”
# 2                     want welcome presidential debate.
# 3     participants tonight Donald Trump Hillary Clin...
# 4     debate sponsored Commission Presidential Debat...
# ...                                                 ...
# 3520                             thing agree hope vote.
# 3521           honors obligations living great country.
# 3522                                  Thank good night.
# 3523                                                  [
# 3524                                         Applause ]
#
#                                              named_ents  \
# 0     [(Hofstra University Hempstead, ORG), (New Yor...
# 1      [(Lester Holt, PERSON), (NBC Nightly News, ORG)]
# 2                                                    []
# 3     [(Donald Trump, PERSON), (Hillary Clinton, PER...
# 4              [(Commission Presidential Debates, ORG)]
# ...                                                 ...
# 3520                                                 []
# 3521                                                 []
# 3522                                    [(night, TIME)]
# 3523                                                 []
# 3524                                                 []
#
#                                                   nouns  \
# 0     [(evening, NOUN), (Hofstra, PROPN), (Universit...
# 1     [(Lester, PROPN), (Holt, PROPN), (anchor, NOUN...
# 2                                      [(debate, NOUN)]
# 3     [(participants, NOUN), (tonight, NOUN), (Donal...
# 4     [(debate, NOUN), (Commission, PROPN), (Preside...
# ...                                                 ...
# 3520        [(thing, NOUN), (hope, NOUN), (vote, NOUN)]
# 3521  [(honors, NOUN), (obligations, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
#                                             named_nouns  \
# 0     [(evening, NOUN), (New, PROPN), (University, P...
# 1     [(anchor, NOUN), (Nightly, PROPN), (NBC, PROPN...
# 2                                      [(debate, NOUN)]
# 3     [(tonight, NOUN), (participants, NOUN), (Trump...
# 4     [(debate, NOUN), (organization, NOUN), (Debate...
# ...                                                 ...
# 3520        [(hope, NOUN), (thing, NOUN), (vote, NOUN)]
# 3521  [(obligations, NOUN), (honors, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
#                                              compounds
# 0     [evening Hofstra University Hempstead, New York]
# 1                      [Lester Holt, NBC Nightly News]
# 2                                                   []
# 3                       [Donald Trump Hillary Clinton]
# 4                    [Commission Presidential Debates]
# ...                                                ...
# 3520                                       [hope vote]
# 3521                              [honors obligations]
# 3522                                                []
# 3523                                                []
# 3524                                                []
#
# [3525 rows x 5 columns]

# %%
def extract_noun_phrases(text):
    return [(chunk.text) for chunk in nlp(text).noun_chunks]

def add_noun_phrases(df):
    df['noun_phrases'] = df['text'].apply(extract_noun_phrases)
add_noun_phrases(df)
display(df)
# Out:
#                                                    text  \
# 0     Good evening Hofstra University Hempstead, New...
# 1               Lester Holt, anchor "NBC Nightly News.”
# 2                     want welcome presidential debate.
# 3     participants tonight Donald Trump Hillary Clin...
# 4     debate sponsored Commission Presidential Debat...
# ...                                                 ...
# 3520                             thing agree hope vote.
# 3521           honors obligations living great country.
# 3522                                  Thank good night.
# 3523                                                  [
# 3524                                         Applause ]
#
#                                              named_ents  \
# 0     [(Hofstra University Hempstead, ORG), (New Yor...
# 1      [(Lester Holt, PERSON), (NBC Nightly News, ORG)]
# 2                                                    []
# 3     [(Donald Trump, PERSON), (Hillary Clinton, PER...
# 4              [(Commission Presidential Debates, ORG)]
# ...                                                 ...
# 3520                                                 []
# 3521                                                 []
# 3522                                    [(night, TIME)]
# 3523                                                 []
# 3524                                                 []
#
#                                                   nouns  \
# 0     [(evening, NOUN), (Hofstra, PROPN), (Universit...
# 1     [(Lester, PROPN), (Holt, PROPN), (anchor, NOUN...
# 2                                      [(debate, NOUN)]
# 3     [(participants, NOUN), (tonight, NOUN), (Donal...
# 4     [(debate, NOUN), (Commission, PROPN), (Preside...
# ...                                                 ...
# 3520        [(thing, NOUN), (hope, NOUN), (vote, NOUN)]
# 3521  [(honors, NOUN), (obligations, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
#                                             named_nouns  \
# 0     [(evening, NOUN), (New, PROPN), (University, P...
# 1     [(anchor, NOUN), (Nightly, PROPN), (NBC, PROPN...
# 2                                      [(debate, NOUN)]
# 3     [(tonight, NOUN), (participants, NOUN), (Trump...
# 4     [(debate, NOUN), (organization, NOUN), (Debate...
# ...                                                 ...
# 3520        [(hope, NOUN), (thing, NOUN), (vote, NOUN)]
# 3521  [(obligations, NOUN), (honors, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
#                                              compounds  \
# 0     [evening Hofstra University Hempstead, New York]
# 1                      [Lester Holt, NBC Nightly News]
# 2                                                   []
# 3                       [Donald Trump Hillary Clinton]
# 4                    [Commission Presidential Debates]
# ...                                                ...
# 3520                                       [hope vote]
# 3521                              [honors obligations]
# 3522                                                []
# 3523                                                []
# 3524                                                []
#
#                                            noun_phrases
# 0           [Good evening Hofstra University Hempstead]
# 1               [Lester Holt, anchor, NBC Nightly News]
# 2                         [welcome presidential debate]
# 3          [participants, Donald Trump Hillary Clinton]
# 4     [debate sponsored Commission Presidential Deba...
# ...                                                 ...
# 3520                                 [thing, hope vote]
# 3521                [honors obligations, great country]
# 3522                                                 []
# 3523                                                 []
# 3524                                         [Applause]
#
# [3525 rows x 6 columns]

# %%
#做统计
df["com_nou_phrase"] = df["compounds"].map(str) + df["noun_phrases"].map(str)
display(df)
# Out:
#                                                    text  \
# 0     Good evening Hofstra University Hempstead, New...
# 1               Lester Holt, anchor "NBC Nightly News.”
# 2                     want welcome presidential debate.
# 3     participants tonight Donald Trump Hillary Clin...
# 4     debate sponsored Commission Presidential Debat...
# ...                                                 ...
# 3520                             thing agree hope vote.
# 3521           honors obligations living great country.
# 3522                                  Thank good night.
# 3523                                                  [
# 3524                                         Applause ]
#
#                                              named_ents  \
# 0     [(Hofstra University Hempstead, ORG), (New Yor...
# 1      [(Lester Holt, PERSON), (NBC Nightly News, ORG)]
# 2                                                    []
# 3     [(Donald Trump, PERSON), (Hillary Clinton, PER...
# 4              [(Commission Presidential Debates, ORG)]
# ...                                                 ...
# 3520                                                 []
# 3521                                                 []
# 3522                                    [(night, TIME)]
# 3523                                                 []
# 3524                                                 []
#
#                                                   nouns  \
# 0     [(evening, NOUN), (Hofstra, PROPN), (Universit...
# 1     [(Lester, PROPN), (Holt, PROPN), (anchor, NOUN...
# 2                                      [(debate, NOUN)]
# 3     [(participants, NOUN), (tonight, NOUN), (Donal...
# 4     [(debate, NOUN), (Commission, PROPN), (Preside...
# ...                                                 ...
# 3520        [(thing, NOUN), (hope, NOUN), (vote, NOUN)]
# 3521  [(honors, NOUN), (obligations, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
#                                             named_nouns  \
# 0     [(evening, NOUN), (New, PROPN), (University, P...
# 1     [(anchor, NOUN), (Nightly, PROPN), (NBC, PROPN...
# 2                                      [(debate, NOUN)]
# 3     [(tonight, NOUN), (participants, NOUN), (Trump...
# 4     [(debate, NOUN), (organization, NOUN), (Debate...
# ...                                                 ...
# 3520        [(hope, NOUN), (thing, NOUN), (vote, NOUN)]
# 3521  [(obligations, NOUN), (honors, NOUN), (country...
# 3522                                    [(night, NOUN)]
# 3523                                                 []
# 3524                                 [(Applause, NOUN)]
#
#                                              compounds  \
# 0     [evening Hofstra University Hempstead, New York]
# 1                      [Lester Holt, NBC Nightly News]
# 2                                                   []
# 3                       [Donald Trump Hillary Clinton]
# 4                    [Commission Presidential Debates]
# ...                                                ...
# 3520                                       [hope vote]
# 3521                              [honors obligations]
# 3522                                                []
# 3523                                                []
# 3524                                                []
#
#                                            noun_phrases  \
# 0           [Good evening Hofstra University Hempstead]
# 1               [Lester Holt, anchor, NBC Nightly News]
# 2                         [welcome presidential debate]
# 3          [participants, Donald Trump Hillary Clinton]
# 4     [debate sponsored Commission Presidential Deba...
# ...                                                 ...
# 3520                                 [thing, hope vote]
# 3521                [honors obligations, great country]
# 3522                                                 []
# 3523                                                 []
# 3524                                         [Applause]
#
#                                          com_nou_phrase
# 0     ['evening Hofstra University Hempstead', 'New ...
# 1     ['Lester Holt', 'NBC Nightly News']['Lester Ho...
# 2                     []['welcome presidential debate']
# 3     ['Donald Trump Hillary Clinton']['participants...
# 4     ['Commission Presidential Debates']['debate sp...
# ...                                                 ...
# 3520                ['hope vote']['thing', 'hope vote']
# 3521  ['honors obligations']['honors obligations', '...
# 3522                                               [][]
# 3523                                               [][]
# 3524                                     []['Applause']
#
# [3525 rows x 7 columns]

# %%
count= df['compounds'].value_counts()
print(count)
# Out:
# []                                           1904
# [Secretary Clinton]                            66
# [Mr. Trump]                                    66
# [President Obama]                              12
# [trade deals]                                   9
#                                              ...
# [security aspect]                               1
# [care people]                                   1
# [education community colleges, peel jobs]       1
# [education disaster]                            1
# [lot Donald]                                    1
# Name: compounds, Length: 1311, dtype: int64

# %%
count3 = df['nouns'].value_counts()
print(count3)
# Out:
# []                                                                                                           554
# [(Secretary, PROPN), (Clinton, PROPN)]                                                                        35
# [(Mr., PROPN), (Trump, PROPN)]                                                                                33
# [(country, NOUN)]                                                                                             20
# [(question, NOUN)]                                                                                            18
#                                                                                                             ...
# [(force, NOUN), (country, NOUN)]                                                                               1
# [(lot, NOUN), (secretary, NOUN), (state, NOUN), (money, NOUN), (campaign, NOUN)]                               1
# [(community, NOUN), (politicians, NOUN), (election, NOUN), (time, NOUN), (election, NOUN), (years, NOUN)]      1
# [(enterprise, NOUN)]                                                                                           1
# [(kind, NOUN), (country, NOUN), (standpoint, NOUN), (industry, NOUN)]                                          1
# Name: nouns, Length: 2440, dtype: int64

# %%
Nouns = df['nouns']
print(Nouns)
# Out:
# 0       [(evening, NOUN), (Hofstra, PROPN), (Universit...
# 1       [(Lester, PROPN), (Holt, PROPN), (anchor, NOUN...
# 2                                        [(debate, NOUN)]
# 3       [(participants, NOUN), (tonight, NOUN), (Donal...
# 4       [(debate, NOUN), (Commission, PROPN), (Preside...
#                               ...
# 3520          [(thing, NOUN), (hope, NOUN), (vote, NOUN)]
# 3521    [(honors, NOUN), (obligations, NOUN), (country...
# 3522                                      [(night, NOUN)]
# 3523                                                   []
# 3524                                   [(Applause, NOUN)]
# Name: nouns, Length: 3525, dtype: object

# %%
Compound = df['noun_phrases']
print(Compound)
# Out:
# 0             [Good evening Hofstra University Hempstead]
# 1                 [Lester Holt, anchor, NBC Nightly News]
# 2                           [welcome presidential debate]
# 3            [participants, Donald Trump Hillary Clinton]
# 4       [debate sponsored Commission Presidential Deba...
#                               ...
# 3520                                   [thing, hope vote]
# 3521                  [honors obligations, great country]
# 3522                                                   []
# 3523                                                   []
# 3524                                           [Applause]
# Name: noun_phrases, Length: 3525, dtype: object

# %%
NE = df['named_ents']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-872459a21068> in <module>
# ----> 1 NE = df['named_ents']
#
# NameError: name 'df' is not defined
